objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.


video = "video_calibracao.mp4"
found = 0
cap = cv2.VideoCapture(video)


path = "./xadrez"

# while(cap.isOpened()):
for frame_num in frames_to_check:
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num-1)
    ret, frame = cap.read()
    if not ret:
        break
    #print(images[im_i])
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Find the chess board corners
    ret, corners = cv2.findChessboardCorners(gray, (7,7), None)
    # If found, add object points, image points (after refining them)
    if ret == True:
        corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
        # Draw and display the corners
        img = cv2.drawChessboardCorners(frame, (7,7), corners2, ret)
        cv2.imshow('img', img)
        cv2.setMouseCallback('img', mouse_callback)
        cv2.waitKey()
        cv2.destroyAllWindows()

        if frame_num in frame_dict.keys() and frame_dict[frame_num]:
            found += 1
            objpoints.append(objp)   # Certainly, every loop objp is the same, in 3D.
            imgpoints.append(corners2)

            # if you want to save images with detected corners 
            # uncomment following 2 lines and lines 5, 18 and 19
            image_name = path + '/calibresult_' + str(found) + '.png'
            cv2.imwrite(image_name, img)
        print(found, "frame:", frame_num )
    if found > 20:
        break

print("Number of images used for calibration: ", found)

# When everything done, release the capture
# cap.release()
cv2.destroyAllWindows()
# Out:
# 0 frame: 116
# 0 frame: 117
# 0 frame: 118
# 0 frame: 119
# 0 frame: 120
# 0 frame: 121
# 0 frame: 122
# 0 frame: 123
# 0 frame: 124
# 0 frame: 125
# 1 frame: 126
# 1 frame: 127
# 1 frame: 128
# 1 frame: 129
# 1 frame: 130
# 1 frame: 131
# 1 frame: 132
# 1 frame: 133
# 1 frame: 134
# 2 frame: 135
# 2 frame: 136
# 2 frame: 137
# 2 frame: 138
# 2 frame: 139
# 2 frame: 140
# 2 frame: 141
# 2 frame: 142
# 3 frame: 143
# 3 frame: 144
# 3 frame: 145
# 3 frame: 146
# 4 frame: 147
# 4 frame: 148
# 4 frame: 149
# 4 frame: 150
# 4 frame: 151
# 4 frame: 152
# 4 frame: 153
# 4 frame: 154
# 4 frame: 155
# 4 frame: 156
# 4 frame: 157
# 4 frame: 158
# 4 frame: 159
# 4 frame: 160
# 4 frame: 161
# 4 frame: 162
# 4 frame: 163
# 4 frame: 164
# 4 frame: 165
# 4 frame: 166
# 4 frame: 167
# 4 frame: 168
# 5 frame: 169
# 5 frame: 170
# 5 frame: 171
# 5 frame: 172
# 5 frame: 173
# 5 frame: 174
# 5 frame: 175
# 5 frame: 176
# 5 frame: 177
# 5 frame: 178
# 5 frame: 179
# 5 frame: 180
# 5 frame: 181
# ...

# %%
# termination criteria
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)
# prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
objp = np.zeros((7*7,3), np.float32)
objp[:,:2] = np.mgrid[0:7,0:7].T.reshape(-1,2)
# Arrays to store object points and image points from all the images.
objpoints = [] # 3d point in real world space
imgpoints = [] # 2d points in image plane.


video = "video_calibracao.mp4"
found = 0
cap = cv2.VideoCapture(video)

frame_num = 100
# cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
path = "./xadrez"

# while(cap.isOpened()):
for frame_num in frames_to_check:
    if frame_num in frame_dict.keys() and frame_dict[frame_num]:

        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num-1)
        ret, frame = cap.read()
        if not ret:
            break
        #print(images[im_i])
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        # Find the chess board corners
        ret, corners = cv2.findChessboardCorners(gray, (7,7), None)
        # If found, add object points, image points (after refining them)
        if ret == True:
            corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
            # Draw and display the corners
            img = cv2.drawChessboardCorners(frame, (7,7), corners2, ret)
            # found += 1
            # cv2.imshow('img', img)
            # cv2.setMouseCallback('img', mouse_callback)
            # cv2.waitKey()
            # cv2.destroyAllWindows()

            found += 1
            objpoints.append(objp)   # Certainly, every loop objp is the same, in 3D.
            imgpoints.append(corners2)
            print(found, "frame:", frame_num )
            # if you want to save images with detected corners 
            # uncomment following 2 lines and lines 5, 18 and 19
            image_name = path + '/calibresult_' + str(found) + '.png'
            cv2.imwrite(image_name, img)
    

print("Number of images used for calibration: ", found)

# When everything done, release the capture
# cap.release()
cv2.destroyAllWindows()
# Out:
# 1 frame: 126
# 2 frame: 135
# 3 frame: 143
# 4 frame: 147
# 5 frame: 169
# 6 frame: 184
# 7 frame: 414
# 8 frame: 428
# 9 frame: 434
# 10 frame: 466
# 11 frame: 467
# 12 frame: 475
# 13 frame: 536
# 14 frame: 538
# 15 frame: 543
# 16 frame: 564
# 17 frame: 570
# 18 frame: 600
# 19 frame: 604
# 20 frame: 634
# 21 frame: 661
# 22 frame: 714
# 23 frame: 715
# 24 frame: 724
# 25 frame: 825
# 26 frame: 834
# 27 frame: 885
# 28 frame: 886
# Number of images used for calibration:  28

# %%
# calibration
ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)

# transform the matrix and distortion coefficients to writable lists
data = {'camera_matrix': np.asarray(mtx).tolist(),
        'dist_coeff': np.asarray(dist).tolist()}

# and save it to a file
with open("calibration_matrix.yaml", "w") as f:
    yaml.dump(data, f)

# %% [markdown]
# ## Show undistorced image

# %%
import yaml
import cv2
import glob
import numpy as np
import random

# %%
with open("calibration_matrix.yaml", "r") as f:
    data = yaml.safe_load(f)
data
# Out:
# {'camera_matrix': [[7399.826827621343, 0.0, 1045.9175570309699],
#   [0.0, 7380.579608208009, 992.1662655253949],
#   [0.0, 0.0, 1.0]],
#  'dist_coeff': [[0.13189837790145703,
#    12.91832534258776,
#    0.027789493753352507,
#    1.1351675807449437e-05,
#    -197.76139780826622]]}

# %%
list_pictures = glob.glob('D:\\Projects\\senai-artigo2\\xadrez\\*.png')
image_num = random.randrange(len(list_pictures))
print(f"chosen {image_num} from {len(list_pictures)}")
img = cv2.imread(list_pictures[image_num])

h,  w = img.shape[:2]
mtx, dist = np.array(data['camera_matrix']), np.array(data['dist_coeff'])

newcameramtx, roi = cv2.getOptimalNewCameraMatrix(mtx, dist, (w,h), 1, (w,h))
# undistort
dst = cv2.undistort(img, mtx, dist, None, newcameramtx)
 
# crop the image
x, y, w, h = roi
dst = dst[y:y+h, x:x+w]
cv2.imshow(f"image {image_num}", dst)
cv2.waitKey(10)
cv2.destroyAllWindows()
# cv2.imwrite('calibresult.png', dst)
# Out:
# chosen 23 from 28

# %%
len(list_pictures)
